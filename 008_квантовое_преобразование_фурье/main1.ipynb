# %% [markdown]
# <img src="image1.png" width="900">

# %%
from qiskit import *
from qiskit.visualization import *
from numpy import *
from numpy.linalg import *
from matplotlib.pyplot import *

# %%
n = 500 # количество точек

# %%
# интервал
t = linspace (0, 20 * pi, n)

# %%
x = sin(t) + sin(2*t)

# %%
plot(t,x, '.')

# %%
# # встроенная функция
# y = fft.fft(x)

# %%
plot(abs(y)) # положительные и отрицательные частоты sin
