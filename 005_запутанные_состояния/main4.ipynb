# %% [markdown]
# <img src="image4.png" width="500">

# %%
from qiskit import *
from qiskit.visualization import *
from numpy import *
from numpy.linalg import *

# %%
sim = Aer.get_backend('aer_simulator') # симулятор квантового компьютера

# %%
qc = QuantumCircuit(2,1) # цепь
qc.h(0) # Гейт Адамара
qc.x(1) 
qc.cx(0,1) # Гейт CNOT
qc.z(1)
qc.measure_all()

# %%
qc.save_statevector() # сохраняем вектор

# %%
qc.draw(output='mpl', initial_state=True)

# %%
result = sim.run(qc).result() # запуск симулятора

# %%
psi = result.get_statevector() # вектор состояния
array_to_latex(psi, prefix="\dfrac{1}{sqrt{2}}(|01>-|10>) = \n") #система колабсирует
# Out:
# $$
# \dfrac{1}{sqrt{2}}(|01>-|10>) =
#
# \begin{bmatrix}
# 0 & 1 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
counts = result.get_counts()
plot_histogram(counts)
